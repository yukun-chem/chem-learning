# %%
from rdkit import Chem
from rdkit.Chem import Descriptors, Draw

m = Chem.MolFromSmiles('CCO')
print("分子量:", Descriptors.MolWt(m))
Draw.MolToImage(m)
# Out:
# 分子量: 46.069
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>
